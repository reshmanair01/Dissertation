# %%
# For sending GET requests from the API
import requests
# For saving access tokens and for file management when creating and adding to the dataset
import os
# For dealing with json responses we receive from the API
import json
# For displaying the data after
import pandas as pd
# For saving the response data in CSV format
import csv
# For parsing the dates received from twitter in readable formats
import datetime
import dateutil.parser
import unicodedata
#To add wait time between requests
import time

# %%
import tweepy
import time
import pandas as pd

# %%
bearer_token = "AAAAAAAAAAAAAAAAAAAAAIWylgEAAAAAXrlfq5WMdS6XOT9ZUzOGooa63aM%3DsaOLRi5RW5raDW9vpefSCFExES0da2gG1MHN25uSj7PgKWx9SC"

# %%
import requests
import os

# Set up Twitter API credentials
bearer_token = bearer_token

# Make an API request
query = "help"
endpoint = "https://api.twitter.com/2/tweets/search/recent"
headers = {
    "Authorization": f"Bearer {bearer_token}",
    "Content-Type": "application/json",
}

params = {
    "query": query,
    "max_results": 10  # Number of tweets to retrieve
}

response = requests.get(endpoint, headers=headers, params=params)

# Process the response
if response.status_code == 200:
    data = response.json()
else:
    print("Error:", response.status_code, response.text)
# Out:
# This is why you need to discuss pain management with your surgeon BEFORE any procedure.
#
# I neglected to before my hysto, and lived to regret it. Tylenol does nothing for me &amp; never has. I had to make a major fuss to get real help. https://t.co/piwtNzYI2s
# RT @sleepiestgurl: the comments on this shit is like "goals" and "girl boss"
#
# i am not a girl boss. i am a victim to capitalism. i am drow…
# @SpeakerMcCarthy Trying to limit necessary spending without reforming the 2017 Trump &amp; earlier Help the Rich First &amp; Best tax bills your GOP keeps pushing on us (which ballooned our deficits &amp; failed to generate the promised growth), now THAT "would be irresponsible."
# i’lllll   get   myself   some   beer   with   or   without   your   help. https://t.co/6g7nWYg8GF
# RT @ivanabedumb: help, el calor me pone tan de malas
# @CatsBearsandMe @Wulf_Helm @MeadHallWench didn’t help you out in return for a cut?
# RT @tweetsricochet: I can't help thinking that this is the Taylor who wrote Would've Could've Should've for the girl who wrote Dear John. A…
# RT @Syamkumarnair: Shruti, a Hindu girl from Kasargod, was befriended by Muslim girls in college. She was converted to Islam and given the…
# @lazyrichie @Patricia344130 Father…happy to help the stupid
# RT @LochNessa93: Help me stuff both holes
#
# $4 Onlyfans💕 https://t.co/ozmG1emHyx

# %%
data
# Out:
# {'data': [{'edit_history_tweet_ids': ['1654965321046937603'],
#    'id': '1654965321046937603',
#    'text': 'This is why you need to discuss pain management with your surgeon BEFORE any procedure. \n\nI neglected to before my hysto, and lived to regret it. Tylenol does nothing for me &amp; never has. I had to make a major fuss to get real help. https://t.co/piwtNzYI2s'},
#   {'edit_history_tweet_ids': ['1654965320048693249'],
#    'id': '1654965320048693249',
#    'text': 'RT @sleepiestgurl: the comments on this shit is like "goals" and "girl boss" \n\ni am not a girl boss. i am a victim to capitalism. i am drow…'},
#   {'edit_history_tweet_ids': ['1654965319570694144'],
#    'id': '1654965319570694144',
#    'text': '@SpeakerMcCarthy Trying to limit necessary spending without reforming the 2017 Trump &amp; earlier Help the Rich First &amp; Best tax bills your GOP keeps pushing on us (which ballooned our deficits &amp; failed to generate the promised growth), now THAT "would be irresponsible."'},
#   {'edit_history_tweet_ids': ['1654965319490838529'],
#    'id': '1654965319490838529',
#    'text': 'i’lllll   get   myself   some   beer   with   or   without   your   help. https://t.co/6g7nWYg8GF'},
#   {'edit_history_tweet_ids': ['1654965318589247489'],
#    'id': '1654965318589247489',
#    'text': 'RT @ivanabedumb: help, el calor me pone tan de malas'},
#   {'edit_history_tweet_ids': ['1654965318022836232'],
#    'id': '1654965318022836232',
#    'text': '@CatsBearsandMe @Wulf_Helm @MeadHallWench didn’t help you out in return for a cut?'},
#   {'edit_history_tweet_ids': ['1654965317985026054'],
#    'id': '1654965317985026054',
#    'text': "RT @tweetsricochet: I can't help thinking that this is the Taylor who wrote Would've Could've Should've for the girl who wrote Dear John. A…"},
#   {'edit_history_tweet_ids': ['1654965317918167040'],
#    'id': '1654965317918167040',
#    'text': 'RT @Syamkumarnair: Shruti, a Hindu girl from Kasargod, was befriended by Muslim girls in college. She was converted to Islam and given the…'},
#   {'edit_history_tweet_ids': ['1654965317909528579'],
#    'id': '1654965317909528579',
#    'text': '@lazyrichie @Patricia344130 Father…happy to help the stupid'},
#   {'edit_history_tweet_ids': ['1654965317733437440'],
#    'id': '1654965317733437440',
#    'text': 'RT @LochNessa93: Help me stuff both holes\n\n$4 Onlyfans💕 https://t.co/ozmG1emHyx'}],
#  'meta': {'newest_id': '1654965321046937603',
#   'oldest_id': '1654965317733437440',
#   'result_count': 10,
#   'next_token': 'b26v89c19zqg8o3fqkg050kw42i3y8j2zntsxvyktimpp'}}
